# %%
import cv2
import glob
import os
import numpy as np
from pathlib import Path
import imageio
from PIL import Image
from matplotlib import pyplot

from wmark import WaterMark

# %%
### MAGIC NUMBERS ###
### MAGIC NUMBERS ###
### MAGIC NUMBERS ###
### MAGIC NUMBERS ###

randomNum = 5

# %%
# Read original image
imgOriginal = WaterMark.imread('TestSetPrint/img-0059.tif')

# Making array an image
pilImg = Image.fromarray(imgOriginal)

# Set WaterMark with seed
wObject = WaterMark(randomNum)

# Mark image
# imgMarked = wObject.embedMark(imgOriginal, factor = ImpactFactor)
# Naming image
# imgMarkedName = f"marked-{str(img.name)}.tif"
print(imgOriginal.shape)
print(pilImg.format)

pyplot.imshow(imgOriginal)
pyplot.show()

pyplot.imshow(pilImg)
pyplot.show()

pyplot.imshow(imgMarked)
pyplot.show()

# Mask image with GCR
# imgGCR = WaterMark.gcrMasking(imgOriginal, imgMarked)
# pilGCR = Image.fromarray(imgGCR)
# Naming image
# imgGCRName = f"gcr-{str(img.name)}"
# Saving image
#cv2.imwrite(imgGCRName, imgGCR)
# imgGCR.save(imgGCRName)
# Out:
# 1
# /usr/local/lib/python3.6/dist-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# (512, 512, 4)
# None
