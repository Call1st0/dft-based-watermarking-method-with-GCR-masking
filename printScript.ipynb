# %%
import cv2
import glob
import os
import numpy as np
from pathlib import Path
import imageio
from PIL import Image, ImageCms
from matplotlib import pyplot
import imageio as io
import skimage.measure as msr

from wmark import WaterMark

# %%
### MAGIC NUMBERS ###
### MAGIC NUMBERS ###
### MAGIC NUMBERS ###
### MAGIC NUMBERS ###

randomNum = 5
wObject = WaterMark(randomNum)

# %%
# Source Directory
srcFolder = 'phaserImage/PhaserImages20200120'
# Source Path
srcPth = Path(srcFolder).resolve()

imgs = srcPth.glob('*.tif')

dstFolder = Path(srcFolder+'marked').resolve()
Path(dstFolder).mkdir(exist_ok = True)

# %%
img1 = WaterMark.imread('phaserImage/PhaserImages20200120/1.tif')
img2 = WaterMark.imread('phaserImage/PhaserImages20200120/2.tif')
img3 = WaterMark.imread('phaserImage/PhaserImages20200120/3.tif')
img4 = WaterMark.imread('phaserImage/PhaserImages20200120/4.tif')
img5 = WaterMark.imread('phaserImage/PhaserImages20200120/5.tif')
img6 = WaterMark.imread('phaserImage/PhaserImages20200120/6.tif')
img7 = WaterMark.imread('phaserImage/PhaserImages20200120/7.tif')
img8 = WaterMark.imread('phaserImage/PhaserImages20200120/8.tif')
img9 = WaterMark.imread('phaserImage/PhaserImages20200120/9.tif')
img10 = WaterMark.imread('phaserImage/PhaserImages20200120/10.tif')

img11 = WaterMark.imread('phaserImage/PhaserImages20200120/11.tif')
img12 = WaterMark.imread('phaserImage/PhaserImages20200120/12.tif')
img13 = WaterMark.imread('phaserImage/PhaserImages20200120/13.tif')
img14 = WaterMark.imread('phaserImage/PhaserImages20200120/14.tif')
img15 = WaterMark.imread('phaserImage/PhaserImages20200120/15.tif')
img16 = WaterMark.imread('phaserImage/PhaserImages20200120/16.tif')
img17 = WaterMark.imread('phaserImage/PhaserImages20200120/17.tif')
img18 = WaterMark.imread('phaserImage/PhaserImages20200120/18.tif')
img19 = WaterMark.imread('phaserImage/PhaserImages20200120/19.tif')
img20 = WaterMark.imread('phaserImage/PhaserImages20200120/20.tif')

img21 = WaterMark.imread('phaserImage/PhaserImages20200120/21.tif')
img22 = WaterMark.imread('phaserImage/PhaserImages20200120/22.tif')
img23 = WaterMark.imread('phaserImage/PhaserImages20200120/23.tif')
img24 = WaterMark.imread('phaserImage/PhaserImages20200120/24.tif')
img25 = WaterMark.imread('phaserImage/PhaserImages20200120/25.tif')
img26 = WaterMark.imread('phaserImage/PhaserImages20200120/26.tif')
img27 = WaterMark.imread('phaserImage/PhaserImages20200120/27.tif')
img28 = WaterMark.imread('phaserImage/PhaserImages20200120/28.tif')
img29 = WaterMark.imread('phaserImage/PhaserImages20200120/29.tif')
img30 = WaterMark.imread('phaserImage/PhaserImages20200120/30.tif')

# %%
Blind_img1 = wObject.embedMark(img1, factor = 0)
Blind_img2 = wObject.embedMark(img2, factor = 0)
Blind_img3 = wObject.embedMark(img3, factor = 0)
Blind_img4 = wObject.embedMark(img4, factor = 0)
Blind_img5 = wObject.embedMark(img5, factor = 0)
Blind_img6 = wObject.embedMark(img6, factor = 0)
Blind_img7 = wObject.embedMark(img7, factor = 0)
Blind_img8 = wObject.embedMark(img8, factor = 0)
Blind_img9 = wObject.embedMark(img9, factor = 0)
Blind_img10 = wObject.embedMark(img10, factor = 0)

Blind_img11 = wObject.embedMark(img11, factor = 0)
Blind_img12 = wObject.embedMark(img12, factor = 0)
Blind_img13 = wObject.embedMark(img13, factor = 0)
Blind_img14 = wObject.embedMark(img14, factor = 0)
Blind_img15 = wObject.embedMark(img15, factor = 0)
Blind_img16 = wObject.embedMark(img16, factor = 0)
Blind_img17 = wObject.embedMark(img17, factor = 0)
Blind_img18 = wObject.embedMark(img18, factor = 0)
Blind_img19 = wObject.embedMark(img19, factor = 0)
Blind_img20 = wObject.embedMark(img20, factor = 0)

Blind_img21 = wObject.embedMark(img21, factor = 0)
Blind_img22 = wObject.embedMark(img22, factor = 0)
Blind_img23 = wObject.embedMark(img23, factor = 0)
Blind_img24 = wObject.embedMark(img24, factor = 0)
Blind_img25 = wObject.embedMark(img25, factor = 0)
Blind_img26 = wObject.embedMark(img26, factor = 0)
Blind_img27 = wObject.embedMark(img27, factor = 0)
Blind_img28 = wObject.embedMark(img28, factor = 0)
Blind_img29 = wObject.embedMark(img29, factor = 0)
Blind_img30 = wObject.embedMark(img30, factor = 0)
# Out:
# /Users/zgebac/miniconda3/envs/img-proc/lib/python3.7/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
imgMarked1 = wObject.embedMark(img1, factor = 1297)
imgMarked2 = wObject.embedMark(img2, factor = 673)
imgMarked3 = wObject.embedMark(img3, factor = 673)
imgMarked4 = wObject.embedMark(img4, factor = 985)
imgMarked5 = wObject.embedMark(img5, factor = 1920)
imgMarked6 = wObject.embedMark(img6, factor = 1297)
imgMarked7 = wObject.embedMark(img7, factor = 1297)
imgMarked8 = wObject.embedMark(img8, factor = 985)
imgMarked9 = wObject.embedMark(img9, factor = 1296)
imgMarked10 = wObject.embedMark(img10, factor = 1297)

imgMarked11 = wObject.embedMark(img11, factor = 1297)
imgMarked12 = wObject.embedMark(img12, factor = 1297)
imgMarked13 = wObject.embedMark(img13, factor = 1297)
imgMarked14 = wObject.embedMark(img14, factor = 985)
imgMarked15 = wObject.embedMark(img15, factor = 985)
imgMarked16 = wObject.embedMark(img16, factor = 1297)
imgMarked17 = wObject.embedMark(img17, factor = 1297)
imgMarked18 = wObject.embedMark(img18, factor = 1297)
imgMarked19 = wObject.embedMark(img19, factor = 673)
imgMarked20 = wObject.embedMark(img20, factor = 985)

imgMarked21 = wObject.embedMark(img21, factor = 673)
imgMarked22 = wObject.embedMark(img22, factor = 1297)
imgMarked23 = wObject.embedMark(img23, factor = 518)
imgMarked24 = wObject.embedMark(img24, factor = 1297)
imgMarked25 = wObject.embedMark(img25, factor = 1920)
imgMarked26 = wObject.embedMark(img26, factor = 985)
imgMarked27 = wObject.embedMark(img27, factor = 985)
imgMarked28 = wObject.embedMark(img28, factor = 985)
imgMarked29 = wObject.embedMark(img29, factor = 673)
imgMarked30 = wObject.embedMark(img30, factor = 1297)

# %%
GCR_imgMarked1 = wObject.gcrMasking(Blind_img1, imgMarked1)
GCR_imgMarked2 = wObject.gcrMasking(Blind_img2, imgMarked2)
GCR_imgMarked3 = wObject.gcrMasking(Blind_img3, imgMarked3)
GCR_imgMarked4 = wObject.gcrMasking(Blind_img4, imgMarked4)
GCR_imgMarked5 = wObject.gcrMasking(Blind_img5, imgMarked5)
GCR_imgMarked6 = wObject.gcrMasking(Blind_img6, imgMarked6)
GCR_imgMarked7 = wObject.gcrMasking(Blind_img7, imgMarked7)
GCR_imgMarked8 = wObject.gcrMasking(Blind_img8, imgMarked8)
GCR_imgMarked9 = wObject.gcrMasking(Blind_img9, imgMarked9)
GCR_imgMarked10 = wObject.gcrMasking(Blind_img10, imgMarked10)

GCR_imgMarked11 = wObject.gcrMasking(Blind_img11, imgMarked11)
GCR_imgMarked12 = wObject.gcrMasking(Blind_img12, imgMarked12)
GCR_imgMarked13 = wObject.gcrMasking(Blind_img13, imgMarked13)
GCR_imgMarked14 = wObject.gcrMasking(Blind_img14, imgMarked14)
GCR_imgMarked15 = wObject.gcrMasking(Blind_img15, imgMarked15)
GCR_imgMarked16 = wObject.gcrMasking(Blind_img16, imgMarked16)
GCR_imgMarked17 = wObject.gcrMasking(Blind_img17, imgMarked17)
GCR_imgMarked18 = wObject.gcrMasking(Blind_img18, imgMarked18)
GCR_imgMarked19 = wObject.gcrMasking(Blind_img19, imgMarked19)
GCR_imgMarked20 = wObject.gcrMasking(Blind_img20, imgMarked20)

GCR_imgMarked21 = wObject.gcrMasking(Blind_img21, imgMarked21)
GCR_imgMarked22 = wObject.gcrMasking(Blind_img22, imgMarked22)
GCR_imgMarked23 = wObject.gcrMasking(Blind_img23, imgMarked23)
GCR_imgMarked24 = wObject.gcrMasking(Blind_img24, imgMarked24)
GCR_imgMarked25 = wObject.gcrMasking(Blind_img25, imgMarked25)
GCR_imgMarked26 = wObject.gcrMasking(Blind_img26, imgMarked26)
GCR_imgMarked27 = wObject.gcrMasking(Blind_img27, imgMarked27)
GCR_imgMarked28 = wObject.gcrMasking(Blind_img28, imgMarked28)
GCR_imgMarked29 = wObject.gcrMasking(Blind_img29, imgMarked29)
GCR_imgMarked30 = wObject.gcrMasking(Blind_img30, imgMarked30)
# Out:
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking
# finished masking

# %%
resultsPSNRlab = np.zeros((30, 2))

resultsPSNRlab[0, 0] = round(WaterMark.labPSNR(Blind_img1, imgMarked1), 2)
resultsPSNRlab[1, 0] = round(WaterMark.labPSNR(Blind_img2, imgMarked2), 2)
resultsPSNRlab[2, 0] = round(WaterMark.labPSNR(Blind_img3, imgMarked3), 2)
resultsPSNRlab[3, 0] = round(WaterMark.labPSNR(Blind_img4, imgMarked4), 2)
resultsPSNRlab[4, 0] = round(WaterMark.labPSNR(Blind_img5, imgMarked5), 2)
resultsPSNRlab[5, 0] = round(WaterMark.labPSNR(Blind_img6, imgMarked6), 2)
resultsPSNRlab[6, 0] = round(WaterMark.labPSNR(Blind_img7, imgMarked7), 2)
resultsPSNRlab[7, 0] = round(WaterMark.labPSNR(Blind_img8, imgMarked8), 2)
resultsPSNRlab[8, 0] = round(WaterMark.labPSNR(Blind_img9, imgMarked9), 2)
resultsPSNRlab[9, 0] = round(WaterMark.labPSNR(Blind_img10, imgMarked10), 2)

resultsPSNRlab[10, 0] = round(WaterMark.labPSNR(Blind_img11, imgMarked11), 2)
resultsPSNRlab[11, 0] = round(WaterMark.labPSNR(Blind_img12, imgMarked12), 2)
resultsPSNRlab[12, 0] = round(WaterMark.labPSNR(Blind_img13, imgMarked13), 2)
resultsPSNRlab[13, 0] = round(WaterMark.labPSNR(Blind_img14, imgMarked14), 2)
resultsPSNRlab[14, 0] = round(WaterMark.labPSNR(Blind_img15, imgMarked15), 2)
resultsPSNRlab[15, 0] = round(WaterMark.labPSNR(Blind_img16, imgMarked16), 2)
resultsPSNRlab[16, 0] = round(WaterMark.labPSNR(Blind_img17, imgMarked17), 2)
resultsPSNRlab[17, 0] = round(WaterMark.labPSNR(Blind_img18, imgMarked18), 2)
resultsPSNRlab[18, 0] = round(WaterMark.labPSNR(Blind_img19, imgMarked19), 2)
resultsPSNRlab[19, 0] = round(WaterMark.labPSNR(Blind_img20, imgMarked20), 2)

resultsPSNRlab[20, 0] = round(WaterMark.labPSNR(Blind_img21, imgMarked21), 2)
resultsPSNRlab[21, 0] = round(WaterMark.labPSNR(Blind_img22, imgMarked22), 2)
resultsPSNRlab[22, 0] = round(WaterMark.labPSNR(Blind_img23, imgMarked23), 2)
resultsPSNRlab[23, 0] = round(WaterMark.labPSNR(Blind_img24, imgMarked24), 2)
resultsPSNRlab[24, 0] = round(WaterMark.labPSNR(Blind_img25, imgMarked25), 2)
resultsPSNRlab[25, 0] = round(WaterMark.labPSNR(Blind_img26, imgMarked26), 2)
resultsPSNRlab[26, 0] = round(WaterMark.labPSNR(Blind_img27, imgMarked27), 2)
resultsPSNRlab[27, 0] = round(WaterMark.labPSNR(Blind_img28, imgMarked28), 2)
resultsPSNRlab[28, 0] = round(WaterMark.labPSNR(Blind_img29, imgMarked29), 2)
resultsPSNRlab[29, 0] = round(WaterMark.labPSNR(Blind_img30, imgMarked30), 2)

# %%
resultsPSNRlab[0, 1] = round(WaterMark.labPSNR(Blind_img1, GCR_imgMarked1), 2)
resultsPSNRlab[1, 1] = round(WaterMark.labPSNR(Blind_img2, GCR_imgMarked2), 2)
resultsPSNRlab[2, 1] = round(WaterMark.labPSNR(Blind_img3, GCR_imgMarked3), 2)
resultsPSNRlab[3, 1] = round(WaterMark.labPSNR(Blind_img4, GCR_imgMarked4), 2)
resultsPSNRlab[4, 1] = round(WaterMark.labPSNR(Blind_img5, GCR_imgMarked5), 2)
resultsPSNRlab[5, 1] = round(WaterMark.labPSNR(Blind_img6, GCR_imgMarked6), 2)
resultsPSNRlab[6, 1] = round(WaterMark.labPSNR(Blind_img7, GCR_imgMarked7), 2)
resultsPSNRlab[7, 1] = round(WaterMark.labPSNR(Blind_img8, GCR_imgMarked8), 2)
resultsPSNRlab[8, 1] = round(WaterMark.labPSNR(Blind_img9, GCR_imgMarked9), 2)
resultsPSNRlab[9, 1] = round(WaterMark.labPSNR(Blind_img10, GCR_imgMarked10), 2)

resultsPSNRlab[10, 1] = round(WaterMark.labPSNR(Blind_img11, GCR_imgMarked11), 2)
resultsPSNRlab[11, 1] = round(WaterMark.labPSNR(Blind_img12, GCR_imgMarked12), 2)
resultsPSNRlab[12, 1] = round(WaterMark.labPSNR(Blind_img13, GCR_imgMarked13), 2)
resultsPSNRlab[13, 1] = round(WaterMark.labPSNR(Blind_img14, GCR_imgMarked14), 2)
resultsPSNRlab[14, 1] = round(WaterMark.labPSNR(Blind_img15, GCR_imgMarked15), 2)
resultsPSNRlab[15, 1] = round(WaterMark.labPSNR(Blind_img16, GCR_imgMarked16), 2)
resultsPSNRlab[16, 1] = round(WaterMark.labPSNR(Blind_img17, GCR_imgMarked17), 2)
resultsPSNRlab[17, 1] = round(WaterMark.labPSNR(Blind_img18, GCR_imgMarked18), 2)
resultsPSNRlab[18, 1] = round(WaterMark.labPSNR(Blind_img19, GCR_imgMarked19), 2)
resultsPSNRlab[19, 1] = round(WaterMark.labPSNR(Blind_img20, GCR_imgMarked20), 2)

resultsPSNRlab[20, 1] = round(WaterMark.labPSNR(Blind_img21, GCR_imgMarked21), 2)
resultsPSNRlab[21, 1] = round(WaterMark.labPSNR(Blind_img22, GCR_imgMarked22), 2)
resultsPSNRlab[22, 1] = round(WaterMark.labPSNR(Blind_img23, GCR_imgMarked23), 2)
resultsPSNRlab[23, 1] = round(WaterMark.labPSNR(Blind_img24, GCR_imgMarked24), 2)
resultsPSNRlab[24, 1] = round(WaterMark.labPSNR(Blind_img25, GCR_imgMarked25), 2)
resultsPSNRlab[25, 1] = round(WaterMark.labPSNR(Blind_img26, GCR_imgMarked26), 2)
resultsPSNRlab[26, 1] = round(WaterMark.labPSNR(Blind_img27, GCR_imgMarked27), 2)
resultsPSNRlab[27, 1] = round(WaterMark.labPSNR(Blind_img28, GCR_imgMarked28), 2)
resultsPSNRlab[28, 1] = round(WaterMark.labPSNR(Blind_img29, GCR_imgMarked29), 2)
resultsPSNRlab[29, 1] = round(WaterMark.labPSNR(Blind_img30, GCR_imgMarked30), 2)

# %%
import pandas as pd
resultsPSNRlab = pd.DataFrame(resultsPSNRlab)

# %%
resultsPSNRlab.columns = ['(Print) Lab PSNR Marked', '(Print) Lab PSNR GCR']
resultsPSNRlab.index += 1

resultsPSNRlab.median()
# Out:
# (Print) Lab PSNR Marked    44.16
# (Print) Lab PSNR GCR       59.01
# dtype: float64

# %%
resultsPSNRlab.describe()
# Out:
#        (Print) Lab PSNR Marked  (Print) Lab PSNR GCR
# count                30.000000             30.000000
# mean                 44.163667             58.661667
# std                   1.578490              1.383135
# min                  40.910000             55.560000
# 25%                  43.070000             57.670000
# 50%                  44.160000             59.010000
# 75%                  45.422500             59.522500
# max                  46.770000             61.610000

# %%
for img in imgs:
    
    imgName = f"{str(dstFolder)}/Marked-{img.name}"

    # Read original image
    imgOriginal = WaterMark.imread(img)

    # Set WaterMark with seed
    wObject = WaterMark(randomNum)

    # Find optimal impact factor value
    ImpactFactor = wObject.findImpactFactor(imgOriginal, rangePSNR=(35, 40), colorMode='LAB')

    # Mark image
    imgMarked1 = wObject.embedMark(imgOriginal, factor = ImpactFactor)

    # Mark image
    # imgMarked2 = wObject.embedMark(imgOriginal, factor = 250)

    # Mark image
    # imgMarked3 = wObject.embedMark(imgOriginal, factor = 1)

    # Mark image
    # imgMarked4 = wObject.embedMark(imgOriginal, factor = 0)
    
    # Compare images for PSNR
    # psnrMarked1 = msr.compare_psnr(imgOriginal, imgMarked1)
    # print(f"Marked 1000: {round(psnrMarked1, 2)}")
    
    # psnrMarked2 = msr.compare_psnr(imgOriginal, imgMarked2)
    # print(f"Marked 250: {round(psnrMarked2, 2)}")
    
    # psnrMarked3 = msr.compare_psnr(imgOriginal, imgMarked3)
    # print(f"Marked 1: {round(psnrMarked3, 2)}")
    
    # psnrMarked1 = msr.compare_psnr(imgOriginal, imgMarked1)
    print(f"Marked {imgName}: {round(ImpactFactor, 0)}")

    # Creating image from array
    # imgPIL = Image.fromarray(imgMarked1)
    
    # imgPIL.mode = 'CMYK'
    # imgWithProfile = ImageCms.buildTransform('profiles/phaserArgyll191119.icm', 
                                             # 'profiles/phaserArgyll191119.icm', 'CMYK', 'CMYK')
    # imgFinal = ImageCms.applyTransform(imgPIL, imgWithProfile)
    
    # imgFinal.save(f"{imgName}", format = 'TIFF')
    # imgPIL.save(f"{imgName}")
# Out:
# 1
# /Users/zgebac/miniconda3/envs/img-proc/lib/python3.7/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# 2
# 3
# 4
# 37.67008701606337
# 1296.875
# Marked /Users/zgebac/Documents/GitHub/dft-based-watermarking-method/phaserImage/PhaserImages20191218marked/Marked-29.tif: 1297.0
# 1
# 2
# 3
# 4
# 5
# 6
# 37.67662792865329
# 1608.59375
# Marked /Users/zgebac/Documents/GitHub/dft-based-watermarking-method/phaserImage/PhaserImages20191218marked/Marked-28.tif: 1609.0
# 1
# 2
# 3
# 4
# 5
# 35.05671353385739
# 1920.3125
# Marked /Users/zgebac/Documents/GitHub/dft-based-watermarking-method/phaserImage/PhaserImages20191218marked/Marked-26.tif: 1920.0
# 1
# 2
# 3
# 4
# 5
# 35.299223461421725
# 1920.3125
# Marked /Users/zgebac/Documents/GitHub/dft-based-watermarking-method/phaserImage/PhaserImages20191218marked/Marked-27.tif: 1920.0
# 1
# 2
# 3
# 39.1759146692967
# 2543.75
# ...

# %%
# Source Directory
srcFolder = 'phaserImage/PhaserImages20191218'
# Source Path
srcPth = Path(srcFolder).resolve()

imgs = srcPth.glob('*.tif')

dstFolder = Path(srcFolder+'gcr').resolve()
Path(dstFolder).mkdir(exist_ok = True)

# %%
for img in imgs:
    
    imgName = f"{str(dstFolder)}/GCR-{img.name}"

    # Read original image
    imgOriginal = WaterMark.imread(img)
    
    # Set WaterMark with seed
    wObject = WaterMark(randomNum)

    # Find optimal impact factor value
    ImpactFactor = wObject.findImpactFactor(imgOriginal, rangePSNR=(35, 40))

    # Mark image
    # imgBlind = wObject.embedMark(imgOriginal, factor = 0) 
    imgMarked = wObject.embedMark(imgOriginal, factor = ImpactFactor) 
    
    # Compare images for PSNR
    # psnrMarked = msr.compare_psnr(imgBlind, imgMarked)
    # print(round(psnrMarked, 2))
    
    # GCR Masking
    imgGCR = WaterMark.gcrMasking(imgOriginal, imgMarked)

    # Creating image from array
    imgPIL = Image.fromarray(imgGCR)
    
    imgPIL.mode = 'CMYK'
    # imgWithProfile = ImageCms.buildTransform('profiles/phaserArgyll191119.icm', 
                                             # 'profiles/phaserArgyll191119.icm', 'CMYK', 'CMYK')
    # imgFinal = ImageCms.applyTransform(imgPIL, imgWithProfile)
    # imgFinal.save(f"{imgName}", format = 'TIFF')
    
    imgPIL.save(f"{imgName}")

# %%
imgLabGCR = WaterMark.profileCmyk2lab(imgGCR, profileCmyk='profiles/ISOcoated_v2_eci.icc')
imgLabBlind = WaterMark.profileCmyk2lab(imgBlind, profileCmyk='profiles/ISOcoated_v2_eci.icc')

# %%
np.shape(imgLabGCR)

# %%
np.shape(imgLabBlind)

# %%
# Source Directory
srcFolder = 'phaserImage/PhaserImages20191126Test'
# Source Path
srcPth = Path(srcFolder).resolve()

imgs = srcPth.glob('*.tif')

dstFolder = Path(srcFolder+'gcr').resolve()
Path(dstFolder).mkdir(exist_ok = True)

# %%
imgName = f"{str(dstFolder)}/GCR-{img.name}"

imgPIL = Image.fromarray(imgLabGCR)
    
imgPIL.mode = 'LAB'
    
imgPIL.save(f"{imgName}")

# %%
# Compare images for PSNR
psnrMarked = msr.compare_psnr(imgLabBlind, imgLabGCR)
print(round(psnrMarked, 2))

# %%
import gcrpywrap

cfAtoB = gcrpywrap.cform('profiles/phaserArgyll191119.icm', 'AtoB1')

imgBlindrs = imgBlind.reshape((np.int(np.size(imgBlind,0)*np.size(imgBlind,1)),4))
imgBlindLAB = cfAtoB.apply(imgBlindrs/2.55)
imgGCRrs = imgMarked.reshape((np.int(np.size(imgGCR,0)*np.size(imgGCR,1)),4))
imgGCRLAB = cfAtoB.apply(imgGCRrs/2.55)

imgBlindLAB = imgBlindLAB.reshape((np.size(imgBlind, 0), np.size(imgBlind, 1), 3))
imgGCRLAB = imgGCRLAB.reshape((np.size(imgGCR, 0), np.size(imgGCR, 1), 3))

# imgName = "BlindLAB"
# imgPIL = Image.fromarray(imgBlindLAB)
# imgPIL.mode = 'LAB'
# imgPIL.save(f"{imgName}")

# imgName = "GCRLAB"
# imgPIL = Image.fromarray(imgGCRLAB)
# imgPIL.mode = 'LAB'
# imgPIL.save(f"{imgName}")

cfAtoB.delete()

# %%
# Compare images for PSNR
psnrLAB = msr.compare_psnr(imgBlindLAB, imgGCRLAB, data_range = 255)
print(f"LAB PSNR: {round(psnrLAB, 2)}")

# %%
import skimage.measure as msr
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.style as style
import pandas as pd
from PIL import Image, ImageCms

import glob
import os
from pathlib import Path
import imageio
import cv2

# Importing class from wmark.py
from wmark import WaterMark

# Source Directory
srcFolder = 'TestSetPrint/marked'
# Source Path
srcPth = Path(srcFolder).resolve()

# Creating empty DataFrame that will fill up after the loop
impactFactorDataframe = pd.DataFrame()
     
# Generating random seed as integer up to 10000
randomNum = 26
print(randomNum)

wObject = WaterMark(randomNum)

# All TIF files in the src_path are now imgs
imgsSource = srcPth.glob('*.tif')
    
# Counting the number of images in src_folder
list = os.listdir(srcFolder)

# -1 because there is one hidden file in directory
numImages = len(list) - 1

# Creating variable for range of possible impact factors
# impFctRange = range(0, 1501, 100)

# Creating zeros Numpy Array and setting counter for results
resultsMarked = np.zeros([numImages, 1])
resultsGCR = np.zeros([numImages, 1])
resultsIF = np.zeros([1, 1])

counter2 = 0
    
for img in imgsSource:

    counter = 0
        
    # Read original image
    imgOriginal = WaterMark.imread(img)
        
    # Find optimal impact factor
    ImpactFactor = wObject.findImpactFactor(imgOriginal)
        
    # Mark image with different Impact Factor values
    imgMarked = wObject.embedMark(imgOriginal, factor = ImpactFactor)
        
    # GCR Masking
    # imgGCR = WaterMark.gcrMasking(imgOriginal, imgMarked)
            
    metricMarked = wObject.decodeMark(imgMarked, 'CORR')
    resultsMarked[counter2, counter] = metricMarked
        
    metricIF = ImpactFactor
    resultsIF[0, counter] = metricIF
        
    counter += 1
    print(ImpactFactor)
    # print(counter)
    # print(counter2)
            
    finalMarked = pd.DataFrame(resultsMarked)
    finalIF = pd.DataFrame(resultsIF)
    impactFactorDataframe = pd.concat([finalMarked], axis = 1)
    counter2 += 1

impactFactorDataframe1 = pd.concat([finalIF, finalMarked], axis = 0)
headers = impactFactorDataframe1.iloc[0]
impactFactorDataframeMarked = pd.DataFrame(impactFactorDataframe1.values[1:], columns=headers)

# %%
impactFactorDataframeMarked

# %%
import skimage.measure as msr
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.style as style
import pandas as pd
from PIL import Image, ImageCms

import glob
import os
from pathlib import Path
import imageio
import cv2

# Importing class from wmark.py
from wmark import WaterMark

# Source Directory
srcFolder = 'TestSetPrint/gcr'
# Source Path
srcPth = Path(srcFolder).resolve()

# Creating empty DataFrame that will fill up after the loop
impactFactorDataframe = pd.DataFrame()
     
# Generating random seed as integer up to 10000
randomNum = 26
print(randomNum)

wObject = WaterMark(randomNum)

# All TIF files in the src_path are now imgs
imgsSource = srcPth.glob('*.tif')
    
# Counting the number of images in src_folder
list = os.listdir(srcFolder)

# -1 because there is one hidden file in directory
numImages = len(list) - 1

# Creating variable for range of possible impact factors
# impFctRange = range(0, 1501, 100)

# Creating zeros Numpy Array and setting counter for results
resultsMarked = np.zeros([numImages, 1])
resultsGCR = np.zeros([numImages, 1])
resultsIF = np.zeros([1, 1])

counter2 = 0
    
for img in imgsSource:

    counter = 0
        
    # Read original image
    imgOriginal = WaterMark.imread(img)
        
    # Find optimal impact factor
    ImpactFactor = wObject.findImpactFactor(imgOriginal)
        
    # Mark image with different Impact Factor values
    imgMarked = wObject.embedMark(imgOriginal, factor = ImpactFactor)
        
    # GCR Masking
    imgGCR = WaterMark.gcrMasking(imgOriginal, imgMarked)
            
    metricGCR = wObject.decodeMark(imgGCR, 'CORR')
    resultsGCR[counter2, counter] = metricGCR
        
    metricIF = ImpactFactor
    resultsIF[0, counter] = metricIF
        
    counter += 1
    print(ImpactFactor)
    # print(counter)
    # print(counter2)
            
    finalGCR = pd.DataFrame(resultsGCR)
    finalIF = pd.DataFrame(resultsIF)
    impactFactorDataframe = pd.concat([finalGCR], axis = 1)
    counter2 += 1

impactFactorDataframe1 = pd.concat([finalIF, finalGCR], axis = 0)
headers = impactFactorDataframe1.iloc[0]
impactFactorDataframeGCR = pd.DataFrame(impactFactorDataframe1.values[1:], columns=headers)

# %%
impactFactorDataframeGCR
