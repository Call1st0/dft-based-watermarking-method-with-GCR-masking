# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np

# %%
# Importing CSV files - different seeds
dfSeed = pd.read_csv('seedDataFrame.csv')

# %%
dfSeed2 = dfSeed.drop(['Seed'], axis = 1)

# %%
dfSeed2
# Out:
#      Correlation
# 0       0.257975
# 1       0.229137
# 2       0.250923
# 3       0.217528
# 4       0.224646
# 5       0.241388
# 6       0.277870
# 7       0.225661
# 8       0.223481
# 9       0.198396
# 10      0.248685
# 11      0.225591
# 12      0.264313
# 13      0.268910
# 14      0.246160
# 15      0.264719
# 16      0.255585
# 17      0.272658
# 18      0.205688
# 19      0.224259
# 20      0.312639
# 21      0.269299
# 22      0.248074
# 23      0.224633
# 24      0.199843
# 25      0.226321
# 26      0.275111
# 27      0.209830
# 28      0.251198
# 29      0.197772
# ..           ...
# 970     0.208511
# 971     0.198377
# 972     0.190412
# 973     0.212728
# 974     0.256332
# 975     0.204630
# 976     0.189590
# 977     0.258345
# 978     0.226834
# 979     0.216775
# 980     0.245074
# 981     0.215250
# 982     0.249302
# 983     0.191980
# 984     0.266565
# 985     0.284608
# 986     0.227181
# 987     0.184611
# 988     0.214826
# 989     0.221209
# 990     0.212243
# 991     0.233720
# 992     0.255534
# 993     0.207166
# 994     0.260355
# 995     0.196230
# 996     0.287261
# 997     0.301203
# 998     0.210723
# 999     0.204657
#
# [1000 rows x 1 columns]

# %%
corr=dfSeed2.values
sizeMarked = np.zeros((1000,1))
sizeMarked[corr>0.5]=100
sizeMarked[corr<0.5]=12.5

# %%
style.use('fivethirtyeight')

graph = dfSeed.plot(kind='scatter', x = 'Seed',y = 'Correlation', s = sizeMarked, figsize = (12, 8))

# Setting rules for labeling axes
graph.tick_params(axis = 'both', which = 'major', labelsize = 12)
graph.set_ylim(bottom=0, top=1)

# Title

# Y value is continuous to values on Y-axis. For instance, 
# if the maximum value is 60, the text can begin at 61.

# Alpha indicates text opacity

graph.text(x = 0, y = 1.13, s = "Seed Results",
               fontsize = 24, weight = 'bold', alpha = .7)

# Creating different lines accross the graph (can be used for important slices of results)
graph.axhline(y = 0.35, color = '#e5ae38', linewidth = 1.25, alpha = 1)
graph.axhline(y = dfSeed2['Correlation'].median(), color = '#6d904f', linewidth = 1.25, alpha = 1)

# Subtitle
graph.text(x = 0, y = 1.04,
               s = "All values except for one are clustered around low values.\nThat one high value represents the correct seed (500).",
              fontsize = 14, alpha = .6)
# Out:
# Text(0, 1.04, 'All values except for one are clustered around low values.\nThat one high value represents the correct seed (500).')
